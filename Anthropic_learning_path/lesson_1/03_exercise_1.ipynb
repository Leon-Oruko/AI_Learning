# %%
from anthropic import Anthropic
client=Anthropic()

messages = []

def add_user_message(messages, message):
    messages.append({"role": "user", "content": message})
    return messages

def add_assistant_message(messages, message):
    messages.append({"role": "assistant", "content": message})
    return messages

def chat(messages):
    response = client.messages.create(
        model="claude-sonnet-4-5",
        messages=messages,
        max_tokens=1000
    )
    return response.content[0].text

# %%
while True:
    user_input = input("You: ")
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("Assistant: ", answer)
# Out:
# Assistant:  1 + 1 = **2**
#
# Simple as that! 😊
#
# Is there anything else you'd like to know?
# Assistant:  The derivative of **ln(x)** is:
#
# **d/dx [ln(x)] = 1/x**
#
# **Key points:**
# - This is valid for x > 0 (since ln(x) is only defined for positive x)
# - This is one of the fundamental derivatives you'll use often in calculus
#
# **Quick proof using the definition:**
# If y = ln(x), then e^y = x
#
# Differentiating both sides:
# - e^y · dy/dx = 1
# - dy/dx = 1/e^y = 1/x
#
# **Related derivatives:**
# - d/dx [ln(u)] = (1/u) · du/dx  (chain rule)
# - d/dx [ln|x|] = 1/x (works for negative x too)
#
# Do you need help with any applications of this derivative or related calculus problems?
# Assistant:  **Portfolio at Risk (PAR)** is a key metric used by SACCOs (Savings and Credit Cooperative Organizations) and microfinance institutions to measure the quality of their loan portfolio.
#
# **Definition:**
# PAR measures the portion of the loan portfolio that is at risk due to late payments. It shows what percentage of outstanding loans has at least one installment overdue.
#
# **Common PAR metrics:**
#
# - **PAR 30**: Percentage of loans with payments overdue by 30+ days
# - **PAR 60**: Overdue by 60+ days
# - **PAR 90**: Overdue by 90+ days
#
# **Formula:**
# ```
# PAR = (Outstanding balance of all loans with payments overdue by X days) / (Total outstanding loan portfolio) × 100
# ```
#
# **Example:**
# If a SACCO has:
# - Total outstanding loans: 10,000,000
# - Loans overdue 30+ days: 500,000
# - PAR 30 = (500,000/10,000,000) × 100 = **5%**
#
# **Why it matters:**
# - **Risk indicator**: Higher PAR means more loans at risk of default
# - **Portfolio health**: Lower PAR indicates better loan collection
# - **Industry standard**: PAR 30 below 5% is generally considered healthy
# - **Management tool**: Helps identify collection problems early
#
# **For SACCOs specifically:**
# Good PAR management is crucial because member deposits fund the loans, so loan defaults directly affect member savings.
#
# Would you like to know more about managing PAR or other SACCO financial metrics?
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[5], line 4
#       1 while True:
#       2     user_input = input("You: ")
#       3     add_user_message(messages, user_input)
# ----> 4     answer = chat(messages)
#       5     add_assistant_message(messages, answer)
#       6     print("Assistant: ", answer)
#
# Cell In[3], line 15, in chat(messages)
#      14 def chat(messages):
# ---> 15     response = client.messages.create(
#      16         model="claude-sonnet-4-5",
#      17         messages=messages,
#      18         max_tokens=1000
#
# File ~/workspace/personal_projects/softwares/AI_Learning/Anthropic_learning_path/venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/workspace/personal_projects/softwares/AI_Learning/Anthropic_learning_path/venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:1018, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1011 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1012     warnings.warn(
#    1013         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1014         UserWarning,
#    1015         stacklevel=3,
#    1016     )
# -> 1018 return self._post(
#    1019     "/v1/messages",
#    1020     body=maybe_transform(
#    1021         {
#    1022             "max_tokens": max_tokens,
#    1023             "messages": messages,
#    1024             "model": model,
#    1025             "cache_control": cache_control,
#    1026             "container": container,
#    1027             "inference_geo": inference_geo,
#    1028             "metadata": metadata,
#    1029             "output_config": output_config,
#    1030             "service_tier": service_tier,
#    1031             "stop_sequences": stop_sequences,
#    1032             "stream": stream,
#    1033             "system": system,
#    1034             "temperature": temperature,
#    1035             "thinking": thinking,
#    1036             "tool_choice": tool_choice,
#    1037             "tools": tools,
#    1038             "top_k": top_k,
#    1039             "top_p": top_p,
#    1040         },
#    1041         message_create_params.MessageCreateParamsStreaming
#    1042         if stream
#    1043         else message_create_params.MessageCreateParamsNonStreaming,
#    1044     ),
#    1045     options=make_request_options(
#    1046         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1047     ),
#    1048     cast_to=Message,
#    1049     stream=stream or False,
#    1050     stream_cls=Stream[RawMessageStreamEvent],
#    1051 )
#
# File ~/workspace/personal_projects/softwares/AI_Learning/Anthropic_learning_path/venv/lib/python3.12/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/workspace/personal_projects/softwares/AI_Learning/Anthropic_learning_path/venv/lib/python3.12/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.16: user messages must have non-empty content'}, 'request_id': 'req_011CcESUMKZ1WXCsvLRC2ax6'}
